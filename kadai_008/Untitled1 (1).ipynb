# %%
import random
var = random.randint(1, 15)

if var == 3 or var == 6 or var == 9 or var == 12:
    print("Fizz")
elif var == 5 or var == 10:
    print("Buzz")
elif var == 15:
    print("FizzaBuzz")
else:
    print(var)
# Out:
# Fizz
